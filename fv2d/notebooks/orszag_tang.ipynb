# %% [markdown]
# ## Orszag-Tang

# %%
from datahandler import Fv2DH5
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt

# %%
home = Path().home() / "Documents"
datapath = "HLLD_DC.h5"

# %%
data = Fv2DH5(datapath)

# %%
data.divB
# Out:
# array([[-0.03847658,  0.00504941,  0.00191162, ...,  0.0051896 ,
#          0.00731986, -0.0175966 ],
#        [-0.03615078, -0.02638626,  0.0015732 , ...,  0.00729384,
#          0.0093561 ,  0.00562236],
#        [-0.00209768, -0.03137675, -0.00839703, ...,  0.00529831,
#          0.00616212,  0.00405482],
#        ...,
#        [ 0.00405459,  0.0061623 ,  0.00529799, ..., -0.0083977 ,
#         -0.03137692, -0.00209741],
#        [ 0.00562218,  0.00935603,  0.00729345, ...,  0.00157383,
#         -0.0263865 , -0.0361509 ],
#        [-0.01759472,  0.00732006,  0.00518953, ...,  0.00191159,
#          0.00504908, -0.03847675]], shape=(512, 512))

# %%
plt.figure()
plt.imshow(data.divB)
plt.tight_layout();
print(np.max(data.divB))
# Out:
# 2.7226972085861663
